# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
import matplotlib.dates as mdates
from datetime import datetime
import calendar

# %%
df = pd.read_csv("Cleaned_sales_data_final.csv")

# %%
df.head()
# Out:
#      Item  Quantity  Price Per Unit  Total Spent  Payment Method  Location  \
# 0  Coffee       2.0             2.0          4.0     Credit Card  Takeaway
# 1    Cake       4.0             3.0         12.0            Cash  In-Store
# 2  Cookie       4.0             1.0          4.0     Credit Card  In-Store
# 3   Salad       2.0             5.0         10.0  Digital Wallet  In-Store
# 4  Coffee       2.0             2.0          4.0  Digital Wallet  In-Store
#
#   Transaction Date  Year  Month Month Name
# 0       2023-09-08  2023      9  September
# 1       2023-05-16  2023      5        May
# 2       2023-07-19  2023      7       July
# 3       2023-04-27  2023      4      April
# 4       2023-06-11  2023      6       June

# %% [markdown]
# ### What is the total revenue generated by each item?

# %%
total_Revenue_each_item = df.groupby(df['Item'])[['Total Spent']].sum().reset_index()
total_Revenue_each_item = total_Revenue_each_item.sort_values(by="Total Spent",ascending=False)
total_Revenue_each_item
# Out:
#        Item  Total Spent
# 4     Salad      17315.0
# 5  Sandwich      13644.0
# 6  Smoothie      13296.0
# 3     Juice      10509.0
# 0      Cake      10377.0
# 1    Coffee       7058.0
# 7       Tea       4929.0
# 2    Cookie       3219.0

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Item', y='Total Spent', data=total_Revenue_each_item, palette='Reds' )
plt.title('What is the total revenue generated by each item?')
plt.xlabel('Item')
plt.ylabel('Total Spent')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HETVI KHADELA\AppData\Local\Temp\ipykernel_4732\2505447189.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Item', y='Total Spent', data=total_Revenue_each_item, palette='Reds' )

# %% [markdown]
# ### Which item has the highest total sales revenue?

# %%
Highest_total_Sales_revenue = total_Revenue_each_item.loc[total_Revenue_each_item['Total Spent'].idxmax(), 'Item']
Highest_total_Sales_revenue
# Out:
# 'Salad'

# %% [markdown]
# ### what is the most ordered item

# %%
most_orderd_item = df.groupby('Item')[['Quantity']].sum().round().reset_index()
most_orderd_item
# Out:
#        Item  Quantity
# 0      Cake    3459.0
# 1    Coffee    3529.0
# 2    Cookie    3219.0
# 3     Juice    3503.0
# 4     Salad    3463.0
# 5  Sandwich    3411.0
# 6  Smoothie    3324.0
# 7       Tea    3286.0

# %%
plt.figure(figsize=(5,5))
colors = sns.color_palette('pastel')

explode = [0.2 if x == most_orderd_item['Quantity'].max() else 0 for x in most_orderd_item['Quantity']]
plt.pie(most_orderd_item['Quantity'], labels=most_orderd_item['Item'], autopct='%1.1f%%', colors=colors, explode=explode)
plt.show()

# %% [markdown]
# ### What are the revenue trends across different months

# %%
revenue_by_month = df.groupby(df['Month Name'])['Total Spent'].sum().reset_index()
revenue_by_month = revenue_by_month.sort_values(by='Total Spent', ascending=False)
revenue_by_month
# Out:
#    Month Name  Total Spent
# 5        July       9916.0
# 10    October       6736.0
# 4     January       6655.0
# 6        June       6613.0
# 7       March       6501.0
# 0       April       6453.5
# 9    November       6428.0
# 2    December       6421.0
# 1      August       6305.0
# 8         May       6204.0
# 11  September       6179.0
# 3    February       5935.5

# %% [markdown]
# ### seasonal spikes

# %%
seasonal_spikes_by_month = df.groupby(['Month Name', 'Item'])['Total Spent'].sum().reset_index()
seasonal_spikes_by_month
# Out:
#    Month Name      Item  Total Spent
# 0       April      Cake        807.0
# 1       April    Coffee        512.0
# 2       April    Cookie        216.0
# 3       April     Juice        915.0
# 4       April     Salad       1460.0
# ..        ...       ...          ...
# 91  September     Juice        735.0
# 92  September     Salad       1180.0
# 93  September  Sandwich       1108.0
# 94  September  Smoothie       1172.0
# 95  September       Tea        417.0
#
# [96 rows x 3 columns]
