# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Cleaned_sales_data_final.csv')

# %%
data.shape
# Out:
# (8979, 7)

# %%
data
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  Payment Method  \
# 0       Coffee       2.0             2.0          4.0     Credit Card
# 1         Cake       4.0             3.0         12.0            Cash
# 2       Cookie       4.0             1.0          4.0     Credit Card
# 3        Salad       2.0             5.0         10.0  Digital Wallet
# 4       Coffee       2.0             2.0          4.0  Digital Wallet
# ...        ...       ...             ...          ...             ...
# 8974  Smoothie       2.0             4.0          8.0            Cash
# 8975    Coffee       2.0             2.0          4.0  Digital Wallet
# 8976    Coffee       4.0             2.0          8.0  Digital Wallet
# 8977    Cookie       3.0             1.0          3.0  Digital Wallet
# 8978  Sandwich       3.0             4.0         12.0            Cash
#
#       Location Transaction Date
# 0     Takeaway       2023-09-08
# 1     In-Store       2023-05-16
# ...

# %%
data.describe()
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  8979.000000     8979.000000  8979.000000
# mean      3.028622        2.950050     8.948324
# std       1.423698        1.279186     6.015953
# min       1.000000        1.000000     1.000000
# 25%       2.000000        2.000000     4.000000
# 50%       3.000000        3.000000     8.000000
# 75%       4.000000        4.000000    12.000000
# max       5.000000        5.000000    25.000000

# %%
data['Transaction Date'] = pd.to_datetime(data['Transaction Date'])

# %%
data['Year'] = data['Transaction Date'].dt.year

# %%
data['Month'] = data['Transaction Date'].dt.month

# %%
data['Month Name'] = data['Transaction Date'].dt.month_name()

# %%
data
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  Payment Method  \
# 0       Coffee       2.0             2.0          4.0     Credit Card
# 1         Cake       4.0             3.0         12.0            Cash
# 2       Cookie       4.0             1.0          4.0     Credit Card
# 3        Salad       2.0             5.0         10.0  Digital Wallet
# 4       Coffee       2.0             2.0          4.0  Digital Wallet
# ...        ...       ...             ...          ...             ...
# 8974  Smoothie       2.0             4.0          8.0            Cash
# 8975    Coffee       2.0             2.0          4.0  Digital Wallet
# 8976    Coffee       4.0             2.0          8.0  Digital Wallet
# 8977    Cookie       3.0             1.0          3.0  Digital Wallet
# 8978  Sandwich       3.0             4.0         12.0            Cash
#
#       Location Transaction Date  Year  Month Month Name
# 0     Takeaway       2023-09-08  2023      9  September
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8979 entries, 0 to 8978
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item              8979 non-null   object
#  1   Quantity          8979 non-null   float64
#  2   Price Per Unit    8979 non-null   float64
#  3   Total Spent       8979 non-null   float64
#  4   Payment Method    8979 non-null   object
#  5   Location          8979 non-null   object
#  6   Transaction Date  8979 non-null   datetime64[ns]
#  7   Year              8979 non-null   int32
#  8   Month             8979 non-null   int32
#  9   Month Name        8979 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(4)
# memory usage: 631.5+ KB

# %%
data.to_csv('Cleaned_sales_data_final.csv', index = False)

# %% [markdown]
# ### Loading same csv to check changes that we just made

# %%
df = pd.read_csv('Cleaned_sales_data_final.csv')

# %%
df
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  Payment Method  \
# 0       Coffee       2.0             2.0          4.0     Credit Card
# 1         Cake       4.0             3.0         12.0            Cash
# 2       Cookie       4.0             1.0          4.0     Credit Card
# 3        Salad       2.0             5.0         10.0  Digital Wallet
# 4       Coffee       2.0             2.0          4.0  Digital Wallet
# ...        ...       ...             ...          ...             ...
# 8974  Smoothie       2.0             4.0          8.0            Cash
# 8975    Coffee       2.0             2.0          4.0  Digital Wallet
# 8976    Coffee       4.0             2.0          8.0  Digital Wallet
# 8977    Cookie       3.0             1.0          3.0  Digital Wallet
# 8978  Sandwich       3.0             4.0         12.0            Cash
#
#       Location Transaction Date  Year  Month Month Name
# 0     Takeaway       2023-09-08  2023      9  September
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8979 entries, 0 to 8978
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item              8979 non-null   object
#  1   Quantity          8979 non-null   float64
#  2   Price Per Unit    8979 non-null   float64
#  3   Total Spent       8979 non-null   float64
#  4   Payment Method    8979 non-null   object
#  5   Location          8979 non-null   object
#  6   Transaction Date  8979 non-null   object
#  7   Year              8979 non-null   int64
#  8   Month             8979 non-null   int64
#  9   Month Name        8979 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 701.6+ KB

# %%
df['Year'].value_counts()
# Out:
# Year
# 2023    8979
# Name: count, dtype: int64

# %%
sorted_df = df.sort_values(by = ['Year', 'Month'])
